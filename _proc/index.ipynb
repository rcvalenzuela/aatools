# %% [raw]
# ---
# description: Utility tools for advanced analytics
# output-file: index.html
# title: aatools
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install

# %% [markdown]
# You can install the package from Pypi using,

# %% [markdown]
# ```sh
# pip install aatools
# ```

# %% [markdown]
# or, if you prefer conda with,

# %% [markdown]
# ```sh
# conda install -c rcvalenzuela aatools
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Currently the package only provides one function [`plot_univariate_continuous`](https://rcvalenzuela.github.io/aatools/eda.html#plot_univariate_continuous) which given a sample of data from a univariate random variable generates the histogram and adds information on the mean and the quartiles

# %% [markdown]
# Look at the [documentation](https://rcvalenzuela.github.io/aatools/) of the package for information on how to use.
