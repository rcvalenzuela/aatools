# %% [raw]
# ---
# description: The datasets module provides auxiliary datasets used to support the package
#   documentation
# output-file: datasets.html
# title: datasets
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Transport dataset

# %% [markdown]
# The [transport](https://www.kaggle.com/datasets/adoumtaiga/transport/download?datasetVersionNumber=1) dataset was originally retrieved from the [Kaggle](https://www.kaggle.com) datasets website. A description of it is available [here](https://www.kaggle.com/datasets/adoumtaiga/transport).
#
# > The dataset contains around 50 individuals answers from a questionaire on their means of transport.
# For each answer we have the Age, Sex, Family Situation, If he has a car, If he has a bike and if he takes public transport
#
# There is some information as well on the monthly income of the respondent

# %%
#|output: asis
#| echo: false
show_doc(load_transport)
# Out:
# ---
#
# [source](https://github.com/rcvalenzuela/aatools/blob/master/aatools/datasets.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_transport
#
# >      load_transport ()
#
# Loads the transport dataset

# %% [markdown]
# To load the dataset simply call the function ...

# %%
transport = load_transport()

# %%
transport.isna().sum()
# Out:
# age          0
# sexe         7
# sitfam       0
# principal    0
# voiture      4
# velo         4
# commun       4
# revenu       3
# dtype: int64

# %% [markdown]
# ### Predictions dataset

# %%
#|output: asis
#| echo: false
show_doc(load_predictions)
# Out:
# ---
#
# [source](https://github.com/rcvalenzuela/aatools/blob/master/aatools/datasets.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_predictions
#
# >      load_predictions ()
#
# Loads the transport dataset

# %%
predictions = load_predictions()

# %%
predictions.head()
# Out:
#    y_true   y_proba
# 0       0  0.283242
# 1       0  0.397620
# 2       0  0.417143
# 3       0  0.376334
# 4       0  0.299264
